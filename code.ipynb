# %%
import pandas as pd

data = pd.read_csv(' call_analysis.csv')

data
# Out:
#                                            Transcript  \
# 0   Customer: Hi, I’m having trouble logging into ...
# 1   Agent: I’m sorry to hear that. Can you tell me...
# 2   Customer: It keeps saying my password is incor...
# 3     Agent: Okay, let’s try resetting your password.
# 4   Customer: Alright, but I don’t want to wait to...
# 5   Agent: Don’t worry, it should be quick. I’ll s...
# 6                     Customer: Thanks, I got it now.
# 7                   Agent: Great! Did the reset work?
# 8   Customer: Yes, I can log in now. That’s a relief.
# 9   Agent: Happy to hear that! Anything else I can...
# 10  Customer: Actually, yes. I was trying to updat...
# 11  Agent: I see. Can you tell me what error messa...
# 12  Customer: It says “Upload failed. Please try a...
# 13  Agent: Got it. Sometimes clearing the cache he...
# 14                     Customer: Not yet. Let me try.
# 15                  Customer: Hmm, still not working.
# ...
